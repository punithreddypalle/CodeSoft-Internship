# %%
#importing the libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # <font color="blue"> Datat Collection  and Preprocessing|

# %%
#reading the dataset
cfd=pd.read_csv("creditcard.csv")
cfd.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
#information of the data
cfd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
#checking size of the data
cfd.size
# Out:
# 8829017

# %%
#checking shape of the data
cfd.shape
# Out:
# (284807, 31)

# %%
#checking null values
cfd.isnull().any()
# Out:
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# Amount    False
# Class     False
# dtype: bool

# %%
cfd.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# # <font color="blue"> Data Analysis

# %%
#description of the data
cfd.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
cfd["Class"].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
#in above the data 0 indicates the valid transaction while 1 indicates the fraud transaction

# %% [markdown]
# # <font color="Blue"> Handling the data

# %%
#droping the column Time
cfd=cfd.drop(columns="Time",axis=1)

# %%
cfd.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %% [markdown]
# # <font color="blue"> Data Visualization

# %%
sns.countplot(x="Class",data=cfd)
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %%
#from above figure we get to know that the value of frauds are less comparatively to Valid transactions.

# %%
#checking the correlation
corr=cfd.corr()
corr
# Out:
#                   V1            V2            V3            V4            V5  \
# V1      1.000000e+00  4.135835e-16 -1.227819e-15 -9.215150e-16  1.812612e-17
# V2      4.135835e-16  1.000000e+00  3.243764e-16 -1.121065e-15  5.157519e-16
# V3     -1.227819e-15  3.243764e-16  1.000000e+00  4.711293e-16 -6.539009e-17
# V4     -9.215150e-16 -1.121065e-15  4.711293e-16  1.000000e+00 -1.719944e-15
# V5      1.812612e-17  5.157519e-16 -6.539009e-17 -1.719944e-15  1.000000e+00
# V6     -6.506567e-16  2.787346e-16  1.627627e-15 -7.491959e-16  2.408382e-16
# V7     -1.005191e-15  2.055934e-16  4.895305e-16 -4.104503e-16  2.715541e-16
# V8     -2.433822e-16 -5.377041e-17 -1.268779e-15  5.697192e-16  7.437229e-16
# V9     -1.513678e-16  1.978488e-17  5.568367e-16  6.923247e-16  7.391702e-16
# V10     7.388135e-17 -3.991394e-16  1.156587e-15  2.232685e-16 -5.202306e-16
# V11     2.125498e-16  1.975426e-16  1.576830e-15  3.459380e-16  7.203963e-16
# ...

# %%
plt.figure(figsize=(25,25))
sns.heatmap(corr,annot=True,cmap="crest")
# Out:
# <Axes: >

# %%
cfd.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount', 'Class'],
#       dtype='object')

# %%
x=cfd[['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
       'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
       'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount']]

# %%
x.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V20       V21       V22       V23  \
# 0  0.098698  0.363787  0.090794  ...  0.251412 -0.018307  0.277838 -0.110474
# 1  0.085102 -0.255425 -0.166974  ... -0.069083 -0.225775 -0.638672  0.101288
# 2  0.247676 -1.514654  0.207643  ...  0.524980  0.247998  0.771679  0.909412
# 3  0.377436 -1.387024 -0.054952  ... -0.208038 -0.108300  0.005274 -0.190321
# 4 -0.270533  0.817739  0.753074  ...  0.408542 -0.009431  0.798278 -0.137458
#
#         V24       V25       V26       V27       V28  Amount
# ...

# %%
y=cfd["Class"]

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Class, dtype: int64

# %% [markdown]
# # <font color="blue"> Splitting data into training and testing

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape,x_test.shape
# Out:
# ((227845, 29), (56962, 29))

# %%
y_train.shape,y_test.shape
# Out:
# ((227845,), (56962,))

# %% [markdown]
# # <font color="blue"> Models Training

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg=LogisticRegression()
log_reg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred_log=log_reg.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_auc_score

# %%
log_acc=accuracy_score(y_test,y_pred_log)
log_acc
# Out:
# 0.9990519995786665

# %%
print(confusion_matrix(y_test,y_pred_log))
# Out:
# [[56853    11]
#  [   43    55]]

# %%
print(classification_report(y_test,y_pred_log))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.83      0.56      0.67        98
#
#     accuracy                           1.00     56962
#    macro avg       0.92      0.78      0.84     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
model_result={}

# %%
model_result["Logistic Regression Default"]=accuracy_score(y_test,y_pred_log)

# %%
model_result
# Out:
# {'Logistic Regression Default': 0.9990519995786665}

# %% [markdown]
# ## Logistic Regression with l1

# %%
log_reg_l1=LogisticRegression(penalty="l1",solver="saga")
log_reg_l1.fit(x_train,y_train)
# Out:
# LogisticRegression(penalty='l1', solver='saga')

# %%
y_pred_log_l1=log_reg_l1.predict(x_test)

# %%
log_l1_acc=accuracy_score(y_test,y_pred_log_l1)
log_l1_acc
# Out:
# 0.9981742214107651

# %%
print(confusion_matrix(y_test,y_pred_log_l1))
# Out:
# [[56853    11]
#  [   93     5]]

# %%
print(classification_report(y_test,y_pred_log_l1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.31      0.05      0.09        98
#
#     accuracy                           1.00     56962
#    macro avg       0.66      0.53      0.54     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
model_result["Logistic Regression with l1"]=accuracy_score(y_test,y_pred_log_l1)

# %%
model_result
# Out:
# {'Logistic Regression Default': 0.9990519995786665,
#  'Logistic Regression with l1': 0.9981742214107651}

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dct=DecisionTreeClassifier()
dct.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_dct=dct.predict(x_test)

# %%
dct_acc=accuracy_score(y_test,y_pred_dct)
dct_acc
# Out:
# 0.9991573329588147

# %%
print(confusion_matrix(y_test,y_pred_dct))
# Out:
# [[56836    28]
#  [   20    78]]

# %%
print(classification_report(y_test,y_pred_dct))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.74      0.80      0.76        98
#
#     accuracy                           1.00     56962
#    macro avg       0.87      0.90      0.88     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
model_result["Decision Tree"]=accuracy_score(y_test,y_pred_dct)

# %%
model_result
# Out:
# {'Logistic Regression Default': 0.9990519995786665,
#  'Logistic Regression with l1': 0.9981742214107651,
#  'Decision Tree': 0.9991573329588147}

# %% [markdown]
# ## K-Nearest Neighbour

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred_knn=knn.predict(x_test)

# %%
knn_acc=accuracy_score(y_test,y_pred_knn)
knn_acc
# Out:
# 0.9993328885923949

# %%
print(confusion_matrix(y_test,y_pred_knn))
# Out:
# [[56862     2]
#  [   36    62]]

# %%
print(classification_report(y_test,y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.97      0.63      0.77        98
#
#     accuracy                           1.00     56962
#    macro avg       0.98      0.82      0.88     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
model_result["K-Neighbors"]=accuracy_score(y_test,y_pred_knn)

# %%
model_result
# Out:
# {'Logistic Regression Default': 0.9990519995786665,
#  'Logistic Regression with l1': 0.9981742214107651,
#  'Decision Tree': 0.9991573329588147,
#  'K-Neighbors': 0.9993328885923949}

# %% [markdown]
# ## Bagging Classifier with Decision Tree

# %%
from sklearn.ensemble import BaggingClassifier

# %%
bag=BaggingClassifier(DecisionTreeClassifier())   
bag.fit(x_train,y_train)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier())

# %%
y_pred_bag=bag.predict(x_test)

# %%
bag_acc=accuracy_score(y_test,y_pred_bag)
bag_acc
# Out:
# 0.9995611109160493

# %%
print(confusion_matrix(y_test,y_pred_bag))
# Out:
# [[56860     4]
#  [   21    77]]

# %%
print(classification_report(y_test,y_pred_bag))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.95      0.79      0.86        98
#
#     accuracy                           1.00     56962
#    macro avg       0.98      0.89      0.93     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
model_result["Bagging Classifier"]=accuracy_score(y_test,y_pred_bag)

# %%
model_result
# Out:
# {'Logistic Regression Default': 0.9990519995786665,
#  'Logistic Regression with l1': 0.9981742214107651,
#  'Decision Tree': 0.9991573329588147,
#  'K-Neighbors': 0.9993328885923949,
#  'Bagging Classifier': 0.9995611109160493}

# %%
models=pd.DataFrame({
    "Model" : ["Logistic Default","Logistic with l1","DecisionTreeClassifier","KNN","BaggingClassifier"],
    "Scores" : [log_acc,log_l1_acc,dct_acc,knn_acc,bag_acc]
})

# %%
models
# Out:
#                     Model    Scores
# 0        Logistic Default  0.999052
# 1        Logistic with l1  0.998174
# 2  DecisionTreeClassifier  0.999157
# 3                     KNN  0.999333
# 4       BaggingClassifier  0.999561

# %%
colors=["lightgreen","hotpink","khaki","tomato","skyblue"]
plt.figure(figsize=(16,8))
sns.barplot(x=models["Model"],y=models["Scores"],palette=colors)
plt.show()

# %%
#from here we get to know that the accuracy of the Bagging Classifier is the Best among all
